# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/MyDrive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/FRCNN/COMP5214_FRCNN-master-new
# Out:
# /content/drive/MyDrive/FRCNN/COMP5214_FRCNN-master-new

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0039.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:31:04.382703: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0039.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  11.93501901626587
# [{'x1': 128, 'x2': 336, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.9966883}]
# [0.9966883]
# IoU = 0.724555443279294
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.3975036144256592
# [{'x1': 112, 'x2': 336, 'y1': 80, 'y2': 336, 'class': 'N95', 'prob': 0.98889065}]
# [0.98889065]
# IoU = 0.6959960737782726
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.3524758815765381
# [{'x1': 112, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.9979073}]
# [0.9979073]
# IoU = 0.7318176971289739
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0034.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:34:03.689838: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0034.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.5327346324920654
# [{'x1': 112, 'x2': 352, 'y1': 48, 'y2': 384, 'class': 'surgical', 'prob': 0.99735606}]
# [0.99735606]
# IoU = 0.893589164400099
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.33487558364868164
# [{'x1': 80, 'x2': 320, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.99122274}]
# [0.99122274]
# IoU = 0.7856604394315029
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.33328723907470703
# [{'x1': 112, 'x2': 352, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9976931}]
# [0.9976931]
# IoU = 0.7310908358791391
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0029.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:35:38.134808: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0029.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.5569818019866943
# [{'x1': 112, 'x2': 368, 'y1': 80, 'y2': 368, 'class': 'surgical', 'prob': 0.9978884}]
# [0.9978884]
# IoU = 0.7473937244452669
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.32508230209350586
# [{'x1': 80, 'x2': 320, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.9933832}]
# [0.9933832]
# IoU = 0.7923169589886585
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.33604884147644043
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9983601}]
# [0.9983601]
# IoU = 0.8311140502853838
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0024.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:37:12.792353: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0024.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.713562250137329
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 384, 'class': 'surgical', 'prob': 0.9961308}, {'x1': 0, 'x2': 64, 'y1': 192, 'y2': 304, 'class': 'no mask', 'prob': 0.55064446}]
# [0.9961308  0.55064446]
# IoU = 0.8000679835041955
# surgical AP: 1.0
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# no mask AP: nan
# mAP = nan
# 2/197
# Elapsed time =  0.30257463455200195
# [{'x1': 96, 'x2': 336, 'y1': 80, 'y2': 368, 'class': 'N95', 'prob': 0.9902378}]
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0019.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:38:47.208074: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0019.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.6822636127471924
# [{'x1': 112, 'x2': 336, 'y1': 80, 'y2': 384, 'class': 'surgical', 'prob': 0.9954209}]
# [0.9954209]
# IoU = 0.759480119081296
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.29498791694641113
# [{'x1': 96, 'x2': 320, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.99697244}]
# [0.99697244]
# IoU = 0.7394958283894145
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.3032228946685791
# [{'x1': 96, 'x2': 320, 'y1': 112, 'y2': 384, 'class': 'N95', 'prob': 0.9996051}]
# [0.9996051]
# IoU = 0.743436568946385
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0014.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:40:18.777932: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0014.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.6952197551727295
# [{'x1': 112, 'x2': 352, 'y1': 80, 'y2': 368, 'class': 'surgical', 'prob': 0.99203134}]
# [0.99203134]
# IoU = 0.7867409718435427
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.2920265197753906
# [{'x1': 80, 'x2': 320, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.9928155}]
# [0.9928155]
# IoU = 0.740403501676232
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.30407214164733887
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 384, 'class': 'N95', 'prob': 0.9973018}]
# [0.9973018]
# IoU = 0.7817527261248293
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0009.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:41:54.061696: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0009.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.5512373447418213
# [{'x1': 112, 'x2': 352, 'y1': 96, 'y2': 384, 'class': 'surgical', 'prob': 0.9783141}, {'x1': 0, 'x2': 80, 'y1': 208, 'y2': 352, 'class': 'no mask', 'prob': 0.7237344}]
# [0.9783141 0.7237344]
# IoU = 0.764529331505699
# surgical AP: 1.0
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# no mask AP: nan
# mAP = nan
# 2/197
# Elapsed time =  0.29784202575683594
# [{'x1': 96, 'x2': 352, 'y1': 80, 'y2': 352, 'class': 'N95', 'prob': 0.99455065}]
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path vgg_result/model_frcnn_0004.hdf5
# Out:
# {0: 'no mask', 1: 'cloth', 2: 'N95', 3: 'surgical', 4: 'improper', 5: 'bg'}
# 2022-05-17 08:43:26.666919: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Loading weights from vgg_result/model_frcnn_0004.hdf5
# Parsing annotation files
# idx=2041/197
# Elapsed time =  2.609795093536377
# [{'x1': 112, 'x2': 336, 'y1': 64, 'y2': 368, 'class': 'surgical', 'prob': 0.98769903}]
# [0.98769903]
# IoU = 0.7802904773777012
# surgical AP: 1.0
# mAP = 1.0
# 2/197
# Elapsed time =  0.29057931900024414
# [{'x1': 96, 'x2': 336, 'y1': 96, 'y2': 368, 'class': 'N95', 'prob': 0.9955161}]
# [0.9955161]
# IoU = 0.740403501676232
# surgical AP: 1.0
# N95 AP: 1.0
# mAP = 1.0
# 3/197
# Elapsed time =  0.2987353801727295
# [{'x1': 96, 'x2': 336, 'y1': 112, 'y2': 384, 'class': 'N95', 'prob': 0.99953556}]
# [0.99953556]
# IoU = 0.7382448443544852
# surgical AP: 1.0
# ...

# %%
# !python measure_map.py -p testMergedLabels.txt -o simple --model_path resnet50_result/model_frcnn_0000.hdf5
